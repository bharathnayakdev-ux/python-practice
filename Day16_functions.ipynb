# %%
x = 78

def test():
     x = 89
     print(x)
test() 
print(x)
# Out:
# 89
# 78

# %%
x = 78

def test():
     global x
     x = 89
     
test() 
print(x)
# Out:
# 89

# %%
x = 78

def test():
     x = 89
     print(x)
     
test() 
print(x)
# Out:
# 89
# 78

# %%
def add(num):
    return list(map(lambda x: x + 2,num))
print(add([2,5]))
# Out:
# [4, 7]

# %%
from functools import reduce

nums = [5,1,2]

result = reduce(lambda a ,b:a - b,nums)
print(result)
# Out:
# 2

# %%
def show(**info):
    return info["name"]

print(show(name = "Bharath",age = 56))
# Out:
# Bharath

# %%
x = 10

def test():
    global x
    x = x + 5
    print(x)

test()
print(x)
# Out:
# 15
# 15

# %%
square = lambda x: x * x
print(square(4))
# Out:
# 16

# %%
nums = [1,4,56]
result = list(map(lambda x: x * 2,nums))
print(result)
# Out:
# [2, 8, 112]

# %%
from functools import reduce

nums = [1,2,3,4]
result = reduce(lambda a,b:a + b,nums)
print(result)
# Out:
# 10
