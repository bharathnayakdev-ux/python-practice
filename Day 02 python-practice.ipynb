# %%
nums = (5,10,15,20)

print(nums[3])
# Out:
# 20

# %%
nums = (1,2,2,3,4,2)

print(nums.count(2))
# Out:
# 3

# %%
nums = (10,20,30,40)

print(nums[3])
# Out:
# 40

# %%
nums = {5,5,10,10,15}

print(nums)
# Out:
# {10, 5, 15}

# %%
nums = {2,4,6,8,10}

print(6 in nums)
print(7 in nums)
# Out:
# True
# False

# %%
nums = {1,2,3}
nums.add(4)
print(nums)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# nums = {10,20,30,40}
#
# nums.remove(30)
#
# print(nums)

# %%
nums = {1,2,3}

nums.add(5)

print(nums)
# Out:
# {1, 2, 3, 5}

# %%
nums = (5,10,15,20)

print(nums[3])
# Out:
# 20

# %%
nums = (1,2,2,3,4,2)

print(nums.count(2))
# Out:
# 3

# %%
nums = ("red","blue","green")

for i in nums:
    print(i)
# Out:
# red
# blue
# green

# %%
nums = (10,25,30,5)

sum = 0
for i in nums:
    sum += i

print(sum)
# Out:
# 70

# %%
nums = (4,7,8,9,2)

count = 0

for i in nums:
    if i % 2 == 0:
        count += 1
print("even =",count)
# Out:
# even = 3

# %%
nums = {1,2,2,3,3,4}

print(nums)
# Out:
# {1, 2, 3, 4}

# %%
nums = {10,20,30}

nums.add(50)
print(nums)
# Out:
# {10, 20, 50, 30}

# %%
nums = {5,10,15,20}

nums.remove(15)
print(nums)
# Out:
# {10, 20, 5}

# %%
a = {1,2,3}
b = {3,4,5}

print(a | b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {10,20,30} 
b = {20,40,50}

print(a & b)
# Out:
# {20}
