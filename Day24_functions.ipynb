# %%
def multiply(a,b=2):
    return a * b
print(multiply(5,4))

# %%
def count_down(n):
    if n == 0:
        return 
    print(n)
    count_down(n - 1)
    

count_down(3)

# %%
x = 78

def test():
     global x
     x = 89
     
test() 
print(x)
