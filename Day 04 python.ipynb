# %%
def add(a,b):
    return a + b
result = add(5,2)
print(result)
# Out:
# 7

# %%
def test():
    x = 10
    print(x)

test()
# Out:
# 10

# %%
x = 100

def show():
    x = 200
    print(x)

show()
print(x)
# Out:
# 200
# 100

# %%
def add(x):
    return x + 5

x = add(x)
print(x)
# Out:
# 105
