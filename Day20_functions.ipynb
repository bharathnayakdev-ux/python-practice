# %%
def test(n):
    if n == 0:
        return 
    print(n)
    test(n - 1)
test(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def test(n):
    if n == 0:
        return 
    test(n - 1)
    print(n)
test(8)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
def odd(n):
    if n == 0:
        return 
    if n % 2 != 0:
        print(n)
 
    odd(n - 1)


odd(7)
# Out:
# 7
# 5
# 3
# 1

# %%
def count_up(n):
    if n == 0:
        return
    count_up(n - 1 ) 
    print(n)
count_up(3)
# Out:
# 1
# 2
# 3
