# %%
def add(a,b):
    return a + b
print(add(7,3))
# Out:
# 10

# %%
def subtract(a,b):
    return a - b
print(subtract(10,4))
# Out:
# 6

# %%
def divide(a,b):
    return a / b
print(divide(20,5))
# Out:
# 4.0

# %%
def multiply(a,b=2):
    return a * b
print(multiply(5,4))
# Out:
# 20

# %%
def add(a = 15,b = 34):
    return a + b

print(add())
# Out:
# 49

# %% [markdown]
# def add(a,b = 5):
#     return a + b
# print(add(10))

# %%
def multiply(a,b=3):
    return a * b
print(multiply(4,5))
# Out:
# 20

# %%
def info(name = "Bharath", age = 18):
    return name + " " + str(age)
print(info(age = 25))
# Out:
# Bharath 25

# %%
def info(name = "Bharath", age = 18):
    return f"{name} {age}"
print(info())
# Out:
# Bharath 18

# %%
def calc(a,b = 2,c = 3):
    return a * b + c
print(calc(5))
# Out:
# 13
